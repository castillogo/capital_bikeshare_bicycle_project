# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import random

# %%
# Xtrue = np.arange(0.0, 1.0, 0.001)
Xtrue = [random.randint(1, 100) * 0.01 for x in range(1000)]

# %%
SLOPE = 2.0
INTERCEPT = -1.5

ytrue = []

for x in Xtrue:
    
    y = SLOPE*x + INTERCEPT + np.random.normal(0, 0.2)
    ytrue.append(y)

ypred = [SLOPE*x + INTERCEPT for x in Xtrue]

# %%
plt.scatter(Xtrue, ytrue, s=0.8)
plt.plot(Xtrue, ypred)
plt.xlabel('X values')
plt.ylabel('Y values')
# Out:
# Text(0, 0.5, 'Y values')

# %%
def make_line(xdata, slope, intercept):
    
    #xdata is a list
    #slope is a single number
    #intercept is a single number
    
    ypred = []
    
    for x in xdata:
        
        y = slope * x + intercept
        
        ypred.append(y)
    
    return ypred #return a list

# %%
plt.scatter(Xtrue, ytrue, s=0.8)
plt.plot(Xtrue, make_line(Xtrue, 1.974, -1.485))

# %% [markdown]
# ### We need a loss function!

# %% [markdown]
# - We, as humans, can tell visually whether or not a line is "good" or "bad".
# - The computer, which obviously can't "see" the picture, needs some kind of measure / number to let it know how "good" or "bad" its guess is.

# %%
def mse(ytrue, ypred): 
    vals = []
    for i, j in list(zip(ytrue, ypred)):
    
        vals.append((i-j)**2)

    error = sum(vals)/len(ytrue)
    return error

# %%
a = [5.0, 4.0, 3.0]
b = [3.0, 2.0, 1.0]

# %%
'''So remember, the best fit of our line is going to be '''
bad_line = make_line(Xtrue, 2.001, -1.5001)
mse(ytrue, bad_line)
plt.plot(Xtrue,ytrue,'.')
plt.plot(Xtrue,ypred)

# %% [markdown]
# lowest error: 0.0364

# %% [markdown]
# ### What we did so far:
#
# - found a way to make a line given any slope and intercept
# - based on the resulting line, we can calculate the error between that line and the actual points
#     - so this helps us determine how good or bad our line is (e.g. compared to a previous attempt)

# %% [markdown]
# ### What do we need to do now?
#
# - now that we have a way of determining the "goodness" or "badness" of a line given some initial guess at the slope and intercept, we need a way to figure out how to actually change the slope and intercept in such a way that our error gets lower!!

# %%
def calc_gradient(Xdata, ytrue, slope, intercept):

    dw = 0.0001
    ypred = make_line(Xdata, slope, intercept) #first guess!
    # a list of numbers

    '''tweak first parameter'''
    slope_change = slope + dw
    ypred_slope = make_line(Xdata, slope_change, intercept) #just tweaking slope!!!
    deriv_slope = (mse(ytrue, ypred_slope) - mse(ytrue, ypred)) / dw

    '''tweak second parameter'''
    intercept_change = intercept + dw
    ypred_intercept = make_line(Xdata, slope, intercept_change)
    deriv_intercept = (mse(ytrue, ypred_intercept) - mse(ytrue, ypred)) / dw

    return [deriv_slope, deriv_intercept]

# %% [markdown]
# The function above basically gives us directionality:
# - Would the error go up or down if I increased slope ever so slightly?
# - Would the error go up or down if I increased intercept ever so slightly?

# %% [markdown]
# ### Now time for the algorithm!!

# %%
import time
import imageio

images = []
SLOPE_START = -8.0
INTERCEPT_START = 2.0
LR = 3 #arbitrary learning rate.
MAX_ITER = 800
THRESHOLD = 0.01
#We hope that this algorithm will eventually take us to the best possible parameters:
    # i.e. slope ~ 2.0 and intercept ~ -1.5


for i in range(MAX_ITER):
    
    time.sleep(0.02)
        
    """1. In each iteration of the loop, calculate the gradient of your loss function."""
    deriv_slope, deriv_intercept = calc_gradient(Xtrue, ytrue, SLOPE_START, INTERCEPT_START)
    

    """2. For each parameter, multiply the corresponding partial derivative by the
    learning rate, then negate it. Add the resulting product to
    the previous value of the parameter to get the updated parameter value."""
    
    SLOPE_NEW -= (deriv_slope * LR + SLOPE_START)
    INTERCEPT_NEW -= (deriv_intercept * LR + INTERCEPT_START)


    """3. At the end of each iteration, overwrite the values of each parameter
    with its modified value."""
    
    SLOPE_START = SLOPE_NEW
    INTERCEPT_START = INTERCEPT_NEW
    #print(SLOPE_START,SLOPE_NEW,'here')
    #print(INTERCEPT_START,INTERCEPT_NEW,'here')

    
    """4. If the gradient becomes smaller than some pre-determined threshold
    value, break out of the loop."""
    
    if i % 20 == 0:
        
        #plt.figure()
       # ypred = make_line(Xtrue, SLOPE_START, INTERCEPT_START)
      #  plt.plot(Xtrue, ypred)
     #   plt.title(f'Iteration Number: {i}, Error: {mse(ytrue, ypred)}')
    #    plt.scatter(Xtrue, ytrue, s=0.8)
   #     filename = f'iter_{i}.png'.format(i)
  #      plt.savefig(filename)  
 #       images.append(imageio.imread(filename))
    
        print(f"Iteration Number: {i}, Deriv_Slope:\
        {deriv_slope},SLOPE: {SLOPE_NEW:.3f}, INTERCEPT: {INTERCEPT_NEW:.3f}")
    

#imageio.mimsave('output.gif', images, fps=10)
#print('Printed GIF!!!')
# Out:
# Iteration Number: 0, Deriv_Slope:        -3.406923695763453,SLOPE: -588276.686, INTERCEPT: -1062949.801
# Iteration Number: 20, Deriv_Slope:        -2232320000.0,SLOPE: 6696960000.000, INTERCEPT: 11934720000.000
# Iteration Number: 40, Deriv_Slope:        0.0,SLOPE: 0.000, INTERCEPT: 0.000
# Iteration Number: 60, Deriv_Slope:        -175.0501658898429,SLOPE: 525.150, INTERCEPT: 947.437
# Iteration Number: 80, Deriv_Slope:        -620800.1708984375,SLOPE: 1862400.513, INTERCEPT: 3365050.049
# Iteration Number: 100, Deriv_Slope:        -2232320000.0,SLOPE: 6696960000.000, INTERCEPT: 11934720000.000
# Iteration Number: 120, Deriv_Slope:        0.0,SLOPE: 0.000, INTERCEPT: 0.000
# Iteration Number: 140, Deriv_Slope:        -175.0501658898429,SLOPE: 525.150, INTERCEPT: 947.437
# Iteration Number: 160, Deriv_Slope:        -620800.1708984375,SLOPE: 1862400.513, INTERCEPT: 3365050.049
# Iteration Number: 180, Deriv_Slope:        -2232320000.0,SLOPE: 6696960000.000, INTERCEPT: 11934720000.000
# Iteration Number: 200, Deriv_Slope:        0.0,SLOPE: 0.000, INTERCEPT: 0.000
# Iteration Number: 220, Deriv_Slope:        -175.0501658898429,SLOPE: 525.150, INTERCEPT: 947.437
# Iteration Number: 240, Deriv_Slope:        -620800.1708984375,SLOPE: 1862400.513, INTERCEPT: 3365050.049
# Iteration Number: 260, Deriv_Slope:        -2232320000.0,SLOPE: 6696960000.000, INTERCEPT: 11934720000.000
# Iteration Number: 280, Deriv_Slope:        0.0,SLOPE: 0.000, INTERCEPT: 0.000
# Iteration Number: 300, Deriv_Slope:        -175.0501658898429,SLOPE: 525.150, INTERCEPT: 947.437
# Iteration Number: 320, Deriv_Slope:        -620800.1708984375,SLOPE: 1862400.513, INTERCEPT: 3365050.049
# Iteration Number: 340, Deriv_Slope:        -2232320000.0,SLOPE: 6696960000.000, INTERCEPT: 11934720000.000
# Iteration Number: 360, Deriv_Slope:        0.0,SLOPE: 0.000, INTERCEPT: 0.000
# Iteration Number: 380, Deriv_Slope:        -175.0501658898429,SLOPE: 525.150, INTERCEPT: 947.437
# Iteration Number: 400, Deriv_Slope:        -620800.1708984375,SLOPE: 1862400.513, INTERCEPT: 3365050.049
# Iteration Number: 420, Deriv_Slope:        -2232320000.0,SLOPE: 6696960000.000, INTERCEPT: 11934720000.000
# Iteration Number: 440, Deriv_Slope:        0.0,SLOPE: 0.000, INTERCEPT: 0.000
# Iteration Number: 460, Deriv_Slope:        -175.0501658898429,SLOPE: 525.150, INTERCEPT: 947.437
# Iteration Number: 480, Deriv_Slope:        -620800.1708984375,SLOPE: 1862400.513, INTERCEPT: 3365050.049
# Iteration Number: 500, Deriv_Slope:        -2232320000.0,SLOPE: 6696960000.000, INTERCEPT: 11934720000.000
# Iteration Number: 520, Deriv_Slope:        0.0,SLOPE: 0.000, INTERCEPT: 0.000
# Iteration Number: 540, Deriv_Slope:        -175.0501658898429,SLOPE: 525.150, INTERCEPT: 947.437
# Iteration Number: 560, Deriv_Slope:        -620800.1708984375,SLOPE: 1862400.513, INTERCEPT: 3365050.049
# Iteration Number: 580, Deriv_Slope:        -2232320000.0,SLOPE: 6696960000.000, INTERCEPT: 11934720000.000
# Iteration Number: 600, Deriv_Slope:        0.0,SLOPE: 0.000, INTERCEPT: 0.000
# Iteration Number: 620, Deriv_Slope:        -175.0501658898429,SLOPE: 525.150, INTERCEPT: 947.437
# Iteration Number: 640, Deriv_Slope:        -620800.1708984375,SLOPE: 1862400.513, INTERCEPT: 3365050.049
# Iteration Number: 660, Deriv_Slope:        -2232320000.0,SLOPE: 6696960000.000, INTERCEPT: 11934720000.000
# Iteration Number: 680, Deriv_Slope:        0.0,SLOPE: 0.000, INTERCEPT: 0.000
# Iteration Number: 700, Deriv_Slope:        -175.0501658898429,SLOPE: 525.150, INTERCEPT: 947.437
# Iteration Number: 720, Deriv_Slope:        -620800.1708984375,SLOPE: 1862400.513, INTERCEPT: 3365050.049
# Iteration Number: 740, Deriv_Slope:        -2232320000.0,SLOPE: 6696960000.000, INTERCEPT: 11934720000.000
# Iteration Number: 760, Deriv_Slope:        0.0,SLOPE: 0.000, INTERCEPT: 0.000
# Iteration Number: 780, Deriv_Slope:        -175.0501658898429,SLOPE: 525.150, INTERCEPT: 947.437
