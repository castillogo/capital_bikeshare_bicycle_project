# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.linear_model import LogisticRegression

# %%
stations = pd.read_csv('stations.csv')

# %%
stations.plot.scatter('lon', 'lat')

# %%
import folium

# %%
washington = folium.Map(location=[38.88, -77.00],
                    zoom_start=10,
                    tiles='OpenStreetMap')
washington
#stations.plot.scatter('lon', 'lat')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from geopy.geocoders import Nominatim

# %%
stations
# Out:
#      station_id                           external_id  \
# 0             1  082469cc-1f3f-11e7-bf6b-3863bb334450
# 1             2  08246b69-1f3f-11e7-bf6b-3863bb334450
# 2             3  08246c35-1f3f-11e7-bf6b-3863bb334450
# 3             4  08246cd5-1f3f-11e7-bf6b-3863bb334450
# 4             5  08246d68-1f3f-11e7-bf6b-3863bb334450
# ..          ...                                   ...
# 574         605  0cabc1c7-cf6f-4afd-9242-c011b77f6330
# 575         606  db81ad06-aad3-4e23-b2b9-05b39b41f8fc
# 576         607  7641069c-42a6-4e3e-9769-7df51da6978d
# 577         608  7a19d0e7-2b3c-4805-b843-1aec84a05bfe
# 578         609  d325a449-32d7-488d-b746-9455ad003834
#
#                                              name  short_name        lat  \
# 0                             Eads St & 15th St S       31000  38.858971
# 1                             18th St & S Eads St       31001  38.857250
# 2                          Crystal Dr & 20th St S       31002  38.856425
# ...

# %%
spiced = folium.Marker(coord, popup='SPICED Academy',
            icon=folium.Icon(icon='star',
            color='orange'))
spiced.add_to(berlin)

berlin.zoom_start = 15
berlin

# %%
stations['longitude'] = stations['lon'].astype(float)

# %%
stations['latitude'] = stations['lat'].astype(float)

# %%
stations
# Out:
#      station_id                           external_id  \
# 0             1  082469cc-1f3f-11e7-bf6b-3863bb334450
# 1             2  08246b69-1f3f-11e7-bf6b-3863bb334450
# 2             3  08246c35-1f3f-11e7-bf6b-3863bb334450
# 3             4  08246cd5-1f3f-11e7-bf6b-3863bb334450
# 4             5  08246d68-1f3f-11e7-bf6b-3863bb334450
# ..          ...                                   ...
# 574         605  0cabc1c7-cf6f-4afd-9242-c011b77f6330
# 575         606  db81ad06-aad3-4e23-b2b9-05b39b41f8fc
# 576         607  7641069c-42a6-4e3e-9769-7df51da6978d
# 577         608  7a19d0e7-2b3c-4805-b843-1aec84a05bfe
# 578         609  d325a449-32d7-488d-b746-9455ad003834
#
#                                              name  short_name        lat  \
# 0                             Eads St & 15th St S       31000  38.858971
# 1                             18th St & S Eads St       31001  38.857250
# 2                          Crystal Dr & 20th St S       31002  38.856425
# ...

# %%
stations = stations.dropna()

# %%
mapit = None
for station in stations:
    mapit = folium.Map( location=[ stations['latitude'], stations['longitude'] ] )

mapit.save( 'washington.html')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\folium\utilities.py in validate_location(location)
#      58         try:
# ---> 59             float(coord)
#      60         except (TypeError, ValueError):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     130             return converter(self.iloc[0])
# --> 131         raise TypeError("cannot convert the series to " "{0}".format(str(converter)))
#     132
#
# TypeError: cannot convert the series to <class 'float'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-83a693331a06> in <module>
#       1 mapit = None
#       2 for station in stations:
# ...

# %%
import folium
import pandas as pd

#create a map
this_map = folium.Map(prefer_canvas=True)

def plotDot(point):
    '''input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map'''
    folium.CircleMarker(location=[point.latitude, point.longitude],
                        radius=2,
                        weight=5).add_to(this_map)

#use df.apply(,axis=1) to "iterate" through every row in your dataframe
stations.apply(plotDot, axis = 1)


#Set the zoom to the maximum possible
this_map.fit_bounds(this_map.get_bounds())

#Save the map to an HTML file
this_map.save('simple_dot_plot.html')

this_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
import pandas as pd

#create a map
this_map2 = folium.Map(prefer_canvas=True)

'''input: series that contains a numeric named latitude and a numeric named longitude
this function creates a CircleMarker and adds it to your this_map'''
folium.CircleMarker(location=[38.888251, -77.049426],
                        radius=2,
                        weight=5).add_to(this_map2)

#use df.apply(,axis=1) to "iterate" through every row in your dataframe


#Set the zoom to the maximum possible
this_map2.fit_bounds(this_map2.get_bounds())

#Save the map to an HTML file
this_map2.save('simple_dot_plot2.html')

this_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
import pandas as pd

#create a map
this_map2 = folium.Map(prefer_canvas=True)

'''input: series that contains a numeric named latitude and a numeric named longitude
this function creates a CircleMarker and adds it to your this_map'''
folium.CircleMarker(location=[38.896960, -77.004930],
                        radius=2,
                        weight=5).add_to(this_map2)

#use df.apply(,axis=1) to "iterate" through every row in your dataframe


#Set the zoom to the maximum possible
this_map2.fit_bounds(this_map2.get_bounds())

#Save the map to an HTML file
this_map2.save('simple_dot_plot2.html')

this_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
