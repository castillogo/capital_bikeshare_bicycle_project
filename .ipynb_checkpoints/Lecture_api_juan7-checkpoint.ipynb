# %%
import pandas as pd
import os
import datetime
import requests
from datetime import datetime

# %%
result = pd.read_csv('resultQ3_D.csv')

# %%
#result_allQs_D

# %%
result['hourlocal'] = result.datetimelocal.str[11:13]

# %%
#result

# %%
result['hour_local'] = result.hourlocal.str[0:2].astype(float)

# %%
#result

# %%
result = result[result.hour_local > 16]

# %%
result = result[result.hour_local < 20]

# %%
result.shape
# Out:
# (1889138, 21)

# %%
result = result[result.latstart > 38.8825]

# %%
result = result[result.latstart < 38.9025]

# %%
result = result[result.lonstart > -77.0677]

# %%
result = result[result.lonstart < -76.9913]

# %%
result.shape
# Out:
# (844668, 21)

# %%
import folium
import pandas as pd

#create a map
this_map = folium.Map(prefer_canvas=True)

def plotDot(point):
    '''input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map'''
    folium.CircleMarker(location=[point.latstart, point.lonstart],
                        radius=2,
                        weight=5).add_to(this_map)

#use df.apply(,axis=1) to "iterate" through every row in your dataframe
result.apply(plotDot, axis = 1)


#Set the zoom to the maximum possible
this_map.fit_bounds(this_map.get_bounds())

#Save the map to an HTML file
#this_map.save('simple_dot_plot.html')

this_map
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-9059b84030c0> in <module>
#      22 #this_map.save('simple_dot_plot.html')
#      23
# ---> 24 this_map
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\displayhook.py in __call__(self, result)
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
# --> 262             format_dict, md_dict = self.compute_format_data(result)
#     263             self.update_user_ns(result)
#     264             self.fill_exec_result(result)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# ...

# %%
# Hi

# %%
result.shape
# Out:
# (844668, 21)

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.preprocessing import PolynomialFeatures, MinMaxScaler
from sklearn.pipeline import make_pipeline

# %%
#result2=result.groupby('Start station number')
#result2=result.groupby(["Start station number"])
result2=result.groupby(["Start station number"]).size().to_frame('count').reset_index()
result3=result.groupby(["Start station number"])

# %%
result3=result3.agg({'atemperatue':'mean','humidity':'mean','temperature':'mean', 'windSpeed':'mean', 'latstart':'mean', 'lonstart':'mean'})

# %%
result2
# Out:
#     Start station number  count
# 0                  31062    132
# 1                  31100   5979
# 2                  31127   5364
# 3                  31129    606
# 4                  31204   6677
# ..                   ...    ...
# 79                 31640   3948
# 80                 31641   9763
# 81                 31642   1592
# 82                 31643   8444
# 83                 31645   2484
#
# [84 rows x 2 columns]

# %%
result3
# Out:
#     Start station number  atemperatue  humidity  temperature  windSpeed  \
# 0                  31062    30.116667  0.532652    28.827045   5.511364
# 1                  31100    28.631007  0.568833    27.383037   4.804482
# 2                  31127    27.464538  0.560488    26.557645   4.520382
# 3                  31129    24.021650  0.428284    23.641469   6.154373
# 4                  31204    28.754912  0.556335    27.563379   4.636984
# ..                   ...          ...       ...          ...        ...
# 79                 31640    28.325704  0.564838    27.215808   4.385557
# 80                 31641    28.448479  0.567196    27.291697   4.647530
# 81                 31642    28.163781  0.575773    27.043725   4.413524
# 82                 31643    28.643727  0.558036    27.456495   4.816296
# 83                 31645    27.675596  0.565519    26.758551   4.239919
#
#      latstart   lonstart
# 0   38.896553 -77.067140
# 1   38.900300 -77.042900
# ...

# %%
result4=result3.merge(result2, on='Start station number')

# %%
result4
# Out:
#     Start station number  atemperatue  humidity  temperature  windSpeed  \
# 0                  31062    30.116667  0.532652    28.827045   5.511364
# 1                  31100    28.631007  0.568833    27.383037   4.804482
# 2                  31127    27.464538  0.560488    26.557645   4.520382
# 3                  31129    24.021650  0.428284    23.641469   6.154373
# 4                  31204    28.754912  0.556335    27.563379   4.636984
# ..                   ...          ...       ...          ...        ...
# 79                 31640    28.325704  0.564838    27.215808   4.385557
# 80                 31641    28.448479  0.567196    27.291697   4.647530
# 81                 31642    28.163781  0.575773    27.043725   4.413524
# 82                 31643    28.643727  0.558036    27.456495   4.816296
# 83                 31645    27.675596  0.565519    26.758551   4.239919
#
#      latstart   lonstart  count
# 0   38.896553 -77.067140    132
# 1   38.900300 -77.042900   5979
# ...

# %%
result4.rename(columns = {'Start station number':'Start_station_number'}, inplace = True)
#result4['Start_Station_Number'] = result.Start_station_number.astype(str)
result4
# Out:
#     Start_station_number  atemperatue  humidity  temperature  windSpeed  \
# 0                  31062    30.116667  0.532652    28.827045   5.511364
# 1                  31100    28.631007  0.568833    27.383037   4.804482
# 2                  31127    27.464538  0.560488    26.557645   4.520382
# 3                  31129    24.021650  0.428284    23.641469   6.154373
# 4                  31204    28.754912  0.556335    27.563379   4.636984
# ..                   ...          ...       ...          ...        ...
# 79                 31640    28.325704  0.564838    27.215808   4.385557
# 80                 31641    28.448479  0.567196    27.291697   4.647530
# 81                 31642    28.163781  0.575773    27.043725   4.413524
# 82                 31643    28.643727  0.558036    27.456495   4.816296
# 83                 31645    27.675596  0.565519    26.758551   4.239919
#
#      latstart   lonstart  count
# 0   38.896553 -77.067140    132
# 1   38.900300 -77.042900   5979
# ...

# %%
result4['Start_Station_Number'] = result4.Start_station_number.astype(str)

# %%
result4
# Out:
#     Start_station_number  atemperatue  humidity  temperature  windSpeed  \
# 0                  31062    30.116667  0.532652    28.827045   5.511364
# 1                  31100    28.631007  0.568833    27.383037   4.804482
# 2                  31127    27.464538  0.560488    26.557645   4.520382
# 3                  31129    24.021650  0.428284    23.641469   6.154373
# 4                  31204    28.754912  0.556335    27.563379   4.636984
# ..                   ...          ...       ...          ...        ...
# 79                 31640    28.325704  0.564838    27.215808   4.385557
# 80                 31641    28.448479  0.567196    27.291697   4.647530
# 81                 31642    28.163781  0.575773    27.043725   4.413524
# 82                 31643    28.643727  0.558036    27.456495   4.816296
# 83                 31645    27.675596  0.565519    26.758551   4.239919
#
#      latstart   lonstart  count Start_Station_Number
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab as pyl

# %matplotlib inline

# %%
result4.plot.bar('Start_Station_Number', 'count')

# %%
result4.head(100)
# Out:
#     Start_station_number  atemperatue  humidity  temperature  windSpeed  \
# 0                  31062    30.116667  0.532652    28.827045   5.511364
# 1                  31100    28.631007  0.568833    27.383037   4.804482
# 2                  31127    27.464538  0.560488    26.557645   4.520382
# 3                  31129    24.021650  0.428284    23.641469   6.154373
# 4                  31204    28.754912  0.556335    27.563379   4.636984
# ..                   ...          ...       ...          ...        ...
# 79                 31640    28.325704  0.564838    27.215808   4.385557
# 80                 31641    28.448479  0.567196    27.291697   4.647530
# 81                 31642    28.163781  0.575773    27.043725   4.413524
# 82                 31643    28.643727  0.558036    27.456495   4.816296
# 83                 31645    27.675596  0.565519    26.758551   4.239919
#
#      latstart   lonstart  count Start_Station_Number
# ...

# %%
result4.sort_values(['count'])
# Out:
#     Start_station_number  atemperatue  humidity  temperature  windSpeed  \
# 0                  31062    30.116667  0.532652    28.827045   5.511364
# 3                  31129    24.021650  0.428284    23.641469   6.154373
# 81                 31642    28.163781  0.575773    27.043725   4.413524
# 83                 31645    27.675596  0.565519    26.758551   4.239919
# 6                  31206    28.449566  0.565858    27.304491   4.739070
# ..                   ...          ...       ...          ...        ...
# 53                 31289    28.571017  0.548885    27.516287   4.496532
# 28                 31248    28.805072  0.550557    27.644052   4.899220
# 27                 31247    28.604829  0.550927    27.534085   4.751296
# 71                 31623    28.846013  0.565946    27.603189   4.755868
# 34                 31258    28.173350  0.553075    27.146359   4.533429
#
#      latstart   lonstart  count Start_Station_Number
# ...
